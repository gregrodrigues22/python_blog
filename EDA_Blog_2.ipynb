# %% [markdown]
# #Set up

# %%
import pandas as pd #principal biblioteca para manipulação de dados
import numpy as np #principal bibllioteca para cálculos matemáticos
import seaborn as sns #uma das principais bibliotecas para visualização de dados
import matplotlib.pyplot as plt #uma das principais bibliotecas para visualização de dados
import plotly.graph_objects as go  #uma das principais bibliotecas para visualização de dados
import datetime as dt #uma das principais bibliotecas para manipulação de datas

# %%
# !pip install missingno
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import missingno as msno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/Shareddrives/Capacitação interna/Publicações Blog/Life Expectancy Data.csv")

# %%
df['Population'].value_counts(dropna=False)
# Out:
# NaN           652
# 444.0           4
# 718239.0        2
# 1141.0          2
# 26868.0         2
#              ...
# 4136.0          1
# 482.0           1
# 43.0            1
# 3978.0          1
# 12222251.0      1
# Name: Population, Length: 2279, dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.query("Population.isnull()")
# Out:
#                   Country  Year      Status  Life expectancy   \
# 64    Antigua and Barbuda  2015  Developing              76.4
# 65    Antigua and Barbuda  2014  Developing              76.2
# 66    Antigua and Barbuda  2013  Developing              76.1
# 67    Antigua and Barbuda  2012  Developing              75.9
# 68    Antigua and Barbuda  2011  Developing              75.7
# ...                   ...   ...         ...               ...
# 2901                Yemen  2004  Developing              62.2
# 2902                Yemen  2003  Developing              61.9
# 2903                Yemen  2002  Developing              61.5
# 2904                Yemen  2001  Developing              61.1
# 2905                Yemen  2000  Developing              68.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 64               13.0              0      NaN                0.000000
# 65              131.0              0     8.56             2422.999774
# ...

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df = df.reset_index()

# %%
df
# Out:
#       index      Country  Year      Status  Life expectancy   Adult Mortality  \
# 0         0  Afghanistan  2015  Developing              65.0            263.0
# 1         1  Afghanistan  2014  Developing              59.9            271.0
# 2         2  Afghanistan  2013  Developing              59.9            268.0
# 3         3  Afghanistan  2012  Developing              59.5            272.0
# 4         4  Afghanistan  2011  Developing              59.2            275.0
# ...     ...          ...   ...         ...               ...              ...
# 2933   2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934   2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935   2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936   2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937   2937     Zimbabwe  2000  Developing              46.0            665.0
#
# ...

# %%
df_pop_null = (
    df.query("Population.isnull()")
    .groupby(['Status'])
    .agg({'index': 'count'})
    .sort_values('index',ascending=False)
    .reset_index()
)

# %%
df_pop_null
# Out:
#        Status  index
# 0  Developing    556
# 1   Developed     96

# %%
plt.pie(df_pop_null['index'], labels = df_pop_null['Status'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad80430c70>,
# ...
#  [Text(-0.984401512899796, 0.49087031016409294, 'Developing'),
#   Text(0.984401512899796, -0.4908703101640931, 'Developed')],
#  [Text(-0.536946279763525, 0.267747441907687, '85.3%'),
#   Text(0.536946279763525, -0.2677474419076871, '14.7%')])

# %%
df.reset_index()
# Out:
#       level_0  index      Country  Year      Status  Life expectancy   \
# 0           0      0  Afghanistan  2015  Developing              65.0
# 1           1      1  Afghanistan  2014  Developing              59.9
# 2           2      2  Afghanistan  2013  Developing              59.9
# 3           3      3  Afghanistan  2012  Developing              59.5
# 4           4      4  Afghanistan  2011  Developing              59.2
# ...       ...    ...          ...   ...         ...               ...
# 2933     2933   2933     Zimbabwe  2004  Developing              44.3
# 2934     2934   2934     Zimbabwe  2003  Developing              44.5
# 2935     2935   2935     Zimbabwe  2002  Developing              44.8
# 2936     2936   2936     Zimbabwe  2001  Developing              45.3
# 2937     2937   2937     Zimbabwe  2000  Developing              46.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  ...  \
# ...

# %%
df.isna().sum()
# Out:
# index                                0
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df = df.dropna(axis=0,thresh=2)

# %%
df = df.dropna(axis=1,how='all')

# %%
df['Status'].value_counts()
# Out:
# 1    2426
# 0     512
# Name: Status, dtype: int64

# %%
df['Status'] = np.where(df['Status'] == "Developed", 0, 1)

# %%
df.dtypes
# Out:
# index                                int64
# Country                             object
# Year                                 int64
# Status                             float64
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# ...

# %%
df_corr = df[['Population','Status']]

# %%
df['Status'] = df['Status'].astype(np.float64)

# %%
msno.heatmap(df)
# Out:
# <Axes: >
